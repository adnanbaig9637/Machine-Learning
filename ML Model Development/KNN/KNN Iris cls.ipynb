# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix
from sklearn.datasets import load_iris
import warnings
warnings.filterwarnings("ignore")

# %%
X,y = load_iris(return_X_y=True , as_frame=True)

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int32

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y , test_size=0.2 , random_state=22)

# %%
X_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 30                 4.8               3.1                1.6               0.2
# 31                 5.4               3.4                1.5               0.4
# 89                 5.5               2.5                4.0               1.3
# 90                 5.5               2.6                4.4               1.2
# 55                 5.7               2.8                4.5               1.3
# ..                 ...               ...                ...               ...
# 102                7.1               3.0                5.9               2.1
# 100                6.3               3.3                6.0               2.5
# 44                 5.1               3.8                1.9               0.4
# 132                6.4               2.8                5.6               2.2
# 117                7.7               3.8                6.7               2.2
#
# [120 rows x 4 columns]

# %%
k_value = []
test_accuracy = []
train_accuracy = []

for i in range(1,21):
    knn = KNeighborsClassifier(n_neighbors=i, p=1,metric='minkowski',)
    knn.fit(X_train , y_train)
    
    y_predict = knn.predict(X_test)
    y_predict_train = knn.predict(X_train)
    
    k_value.append(i)
    
    accuracy_test = accuracy_score(y_test , y_predict)
    accuracy_train = accuracy_score(y_train , y_predict_train)
    
    test_accuracy.append(accuracy_test)
    train_accuracy.append(accuracy_train)

df_accuracy = pd.DataFrame({"K" : k_value ,"Train Accuracy" : train_accuracy, "Test Accuracy" : test_accuracy })
df_accuracy
# Out:
#      K  Train Accuracy  Test Accuracy
# 0    1        1.000000       0.966667
# 1    2        0.966667       0.900000
# 2    3        0.958333       0.966667
# 3    4        0.975000       0.933333
# 4    5        0.975000       0.933333
# 5    6        0.966667       0.933333
# 6    7        0.966667       0.933333
# 7    8        0.966667       0.900000
# 8    9        0.975000       0.933333
# 9   10        0.966667       0.900000
# 10  11        0.975000       0.933333
# 11  12        0.958333       0.900000
# 12  13        0.975000       0.933333
# 13  14        0.975000       0.900000
# 14  15        0.975000       0.933333
# 15  16        0.966667       0.900000
# 16  17        0.966667       0.900000
# 17  18        0.966667       0.900000
# 18  19        0.966667       0.900000
# 19  20        0.958333       0.900000

# %%
df_accuracy = pd.DataFrame({"K" : k_value ,"Train Accuracy" : train_accuracy, "Test Accuracy" : test_accuracy })
df_accuracy
# Out:
#      K  Train Accuracy  Test Accuracy
# 0    1        1.000000       0.966667
# 1    2        0.966667       0.900000
# 2    3        0.958333       0.966667
# 3    4        0.975000       0.933333
# 4    5        0.975000       0.933333
# 5    6        0.966667       0.933333
# 6    7        0.966667       0.933333
# 7    8        0.966667       0.900000
# 8    9        0.975000       0.933333
# 9   10        0.966667       0.900000
# 10  11        0.975000       0.933333
# 11  12        0.958333       0.900000
# 12  13        0.975000       0.933333
# 13  14        0.975000       0.900000
# 14  15        0.975000       0.933333
# 15  16        0.966667       0.900000
# 16  17        0.966667       0.900000
# 17  18        0.966667       0.900000
# 18  19        0.966667       0.900000
# 19  20        0.958333       0.900000

# %%
sns.lineplot(data = df_accuracy , x = 'K' , y = 'Train Accuracy')
# Out:
# <Axes: xlabel='K', ylabel='Train Accuracy'>

# %%
sns.lineplot(data = df_accuracy , x = 'K' , y = 'Test Accuracy')
# Out:
# <Axes: xlabel='K', ylabel='Test Accuracy'>

# %%
sns.lineplot(data = df_accuracy , x = 'K' , y = 'Train Accuracy')
sns.lineplot(data = df_accuracy , x = 'K' , y = 'Test Accuracy')
# Out:
# <Axes: xlabel='K', ylabel='Train Accuracy'>

# %%
k_value = []
test_accuracy = []
train_accuracy = []

X,y = load_iris(return_X_y=True , as_frame=True)
X_train , X_test , y_train , y_test = train_test_split(X,y , test_size=0.2 , random_state=16)
for i in range(1,20):
    knn = KNeighborsClassifier(n_neighbors=i, p=1,metric='minkowski',)
    knn.fit(X_train , y_train)
    
    y_predict = knn.predict(X_test)
    y_predict_train = knn.predict(X_train)
    
    k_value.append(i)
    
    accuracy_test = accuracy_score(y_test , y_predict)
    accuracy_train = accuracy_score(y_train , y_predict_train)
    
    test_accuracy.append(accuracy_test)
    train_accuracy.append(accuracy_train)

df_accuracy = pd.DataFrame({"K" : k_value ,"Train Accuracy" : train_accuracy, "Test Accuracy" : test_accuracy })
sns.lineplot(data = df_accuracy , x = 'K' , y = 'Train Accuracy')
sns.lineplot(data = df_accuracy , x = 'K' , y = 'Test Accuracy')
# Out:
# <Axes: xlabel='K', ylabel='Train Accuracy'>

# %%
from sklearn.model_selection import KFold , cross_val_score

# %%
k_value = []
test_accuracy = []
train_accuracy = []

X,y = load_iris(return_X_y=True , as_frame=True)
for i in range(1,20):
    knn = KNeighborsClassifier(n_neighbors=i, p=1,metric='minkowski',)
    k_fold = KFold(n_splits= 5, shuffle = True , random_state = 44)
    cross_val_acc = cross_val_score(knn,X,y,cv = k_fold ,scoring='accuracy')
    print(cross_val_acc)
# Out:
# [0.93333333 0.96666667 1.         0.93333333 0.93333333]
# [0.86666667 0.96666667 1.         0.93333333 0.93333333]
# [0.96666667 1.         1.         0.93333333 0.93333333]
# [0.9        0.93333333 1.         0.93333333 0.9       ]
# [0.93333333 0.93333333 1.         0.93333333 0.93333333]
# [0.93333333 0.93333333 1.         0.93333333 0.96666667]
# [0.96666667 0.93333333 1.         0.86666667 0.96666667]
# [0.96666667 0.93333333 1.         0.86666667 0.96666667]
# [0.96666667 0.93333333 1.         0.9        0.96666667]
# [0.96666667 0.93333333 1.         0.86666667 0.93333333]
# [0.96666667 0.96666667 1.         0.9        0.96666667]
# [0.96666667 0.93333333 0.96666667 0.93333333 0.93333333]
# [0.96666667 0.96666667 0.96666667 0.93333333 0.96666667]
# [0.96666667 0.96666667 0.96666667 0.93333333 0.93333333]
# [0.96666667 0.96666667 1.         0.93333333 0.96666667]
# [0.96666667 0.96666667 1.         0.93333333 0.96666667]
# [0.96666667 0.96666667 1.         0.93333333 0.96666667]
# [0.96666667 0.96666667 1.         0.93333333 0.93333333]
# [0.96666667 0.96666667 1.         0.93333333 0.96666667]

# %%
k_value = []
validation_acc = []

X,y = load_iris(return_X_y=True , as_frame=True)
for i in range(1,20):
    knn = KNeighborsClassifier(n_neighbors=i, p=1,metric='minkowski',)
    k_fold = KFold(n_splits= 5, shuffle = True , random_state = 22)
    cross_val_acc = cross_val_score(knn,X,y,cv = k_fold ,scoring='accuracy')
    k_value.append(i)
    validation_acc.append(cross_val_acc.mean())
    
    
df_validation = pd.DataFrame({"K":k_value , "Validation Accuracy ":validation_acc})
df_validation
# Out:
#      K  Validation Accuracy
# 0    1              0.953333
# 1    2              0.940000
# 2    3              0.953333
# 3    4              0.946667
# 4    5              0.946667
# 5    6              0.946667
# 6    7              0.940000
# 7    8              0.933333
# 8    9              0.940000
# 9   10              0.940000
# 10  11              0.946667
# 11  12              0.940000
# 12  13              0.953333
# 13  14              0.940000
# 14  15              0.946667
# 15  16              0.940000
# 16  17              0.940000
# 17  18              0.946667
# 18  19              0.940000

# %% [markdown]
# **COmparing Train acc and Validation Acc**

# %%
sns.lineplot(data = df_accuracy , x = 'K' , y = 'Train Accuracy')
sns.lineplot(data = df_validation , x = 'K' , y = 'Validation Accuracy ')
# Out:
# <Axes: xlabel='K', ylabel='Train Accuracy'>
