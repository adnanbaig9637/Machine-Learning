# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from sklearn.ensemble import VotingClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import warnings
warnings.filterwarnings("ignore")

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OrdinalEncoder , OneHotEncoder , LabelEncoder

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\airlines_delay.csv")
df
# Out:
#         Flight    Time  Length Airline AirportFrom AirportTo  DayOfWeek  Class
# 0       2313.0  1296.0   141.0      DL         ATL       HOU          1      0
# 1       6948.0   360.0   146.0      OO         COS       ORD          4      0
# 2       1247.0  1170.0   143.0      B6         BOS       CLT          3      0
# 3         31.0  1410.0   344.0      US         OGG       PHX          6      0
# 4        563.0   692.0    98.0      FL         BMI       ATL          4      0
# ...        ...     ...     ...     ...         ...       ...        ...    ...
# 539377  6973.0   530.0    72.0      OO         GEG       SEA          5      1
# 539378  1264.0   560.0   115.0      WN         LAS       DEN          4      1
# 539379  5209.0   827.0    74.0      EV         CAE       ATL          2      1
# 539380   607.0   715.0    65.0      WN         BWI       BUF          4      1
# 539381  6377.0   770.0    55.0      OO         CPR       DEN          2      1
#
# ...

# %%
df.shape
# Out:
# (539382, 8)

# %%
df.columns
# Out:
# Index(['Flight', 'Time', 'Length', 'Airline', 'AirportFrom', 'AirportTo',
#        'DayOfWeek', 'Class'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 216618

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.duplicated().sum())
print(df.shape)
# Out:
# 0
# (322764, 8)

# %%
#Dropping unwanted column
df.drop('Flight' , axis=1 , inplace=True)
df.drop('Length' , axis=1 , inplace=True)

# %% [markdown]
# **Splitting data**

# %%
X = df.drop('Class' , axis=1)
y = df['Class']

X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.25 , random_state=23)

# %%
ohe = OneHotEncoder(drop = 'first')

# %%
df_cat = X_train.select_dtypes(include='object').columns
df_num = X_train.select_dtypes(exclude='object').columns

# %%
ct = ColumnTransformer([("OHE" , ohe , df_cat)])
ct.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('OHE', OneHotEncoder(drop='first'),
#                                  Index(['Airline', 'AirportFrom', 'AirportTo'], dtype='object'))])

# %%
pipeline = Pipeline([('Cat Transformer' , ct),
                     ('Model' , LogisticRegression())])

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('Cat Transformer',
#                  ColumnTransformer(transformers=[('OHE',
#                                                   OneHotEncoder(drop='first'),
#                                                   Index(['Airline', 'AirportFrom', 'AirportTo'], dtype='object'))])),
#                 ('Model', LogisticRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
metrics.accuracy_score(y_test , y_pred)
# Out:
# 0.589830340434497

# %% [markdown]
# **Random forest**

# %%
pipeline = Pipeline([('Cat Transformer' , ct),
                     ('Model' , RandomForestClassifier(n_estimators=100))])

pipeline.fit(X_train,y_train)
y_pred = pipeline.predict(X_test)
metrics.accuracy_score(y_test , y_pred)
# Out:
# 0.5728395979725124

# %% [markdown]
# **Bagging**

# %%
#Logistic

log = LogisticRegression()
log.fit(X_train , y_train)

#KNN

knn = KNeighborsClassifier()
knn.fit(X_train , y_train)

#DT

dt = DecisionTreeClassifier()
dt.fit(X_train , y_train)

#SVM

svc = SVC()
svc.fit(X_train , y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       1 #Logistic
#       3 log = LogisticRegression()
# ----> 4 log.fit(X_train , y_train)
#       6 #KNN
#       8 knn = KNeighborsClassifier()
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1201, in LogisticRegression.fit(self, X, y, sample_weight)
#    1198 else:
#    1199     _dtype = [np.float64, np.float32]
# -> 1201 X, y = self._validate_data(
#    1202     X,
# ...

# %%
#estimater give algorithm
# n_esti how many time algorithm will run
bag = BaggingClassifier(estimator=dt , n_estimators=10 , verbose=2)
bag.fit(X_train , y_train)

y_pred = bag.predict(X_test)
metrics.accuracy_score(y_test , y_pred)
